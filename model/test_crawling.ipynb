# %%
from utils import get_top_30, get_all_top_30

# %%
get_all_top_30()
# Out:
#                                                title  \
# 0    [속보] 문 대통령 “코로나19 치료제·백신 개발, 우리가 앞서가야…2100억 투자”
# 1                    [속보]오세훈 후보에게 흉기 든 괴한 접근하다 제압 당해
# 2                  문 대통령 "우리의 치료제와 백신으로 인류생명 구하길 기대"
# 3                         "곧 터진다" 여권서 연일 나오는 음모론의 정체
# 4         文대통령 "치료제·백신은 코로나19 극복 위해 반드시 넘어야 할 산"(속보)
# ..                                               ...
# 145            "갤Z플립, 레이저보다 대부분 우수…외부 디스플레이 기능은 뒤처져"
# 146                    6시간→20분으로...코로나 진단 시간 크게 줄어든다
# 147                 또 뒤늦게 … "韓입국 막은 88곳 비자면제 등 잠정중단"
# 148                    삼성전자, 비스포크 냉장고 15가지 도어 패널로 확대
# 149                        LG전자, 'G' 뗀 새 스마트폰 디자인 공개
#
#                                                   text  \
# 0               문재인 대통령이 9일 오전 경기도 성남에 위치한 한국파스퇴르연구...
# 1              서울 광진을에 출마한 오세훈 후보가 탑승한 유세 차량에 한 괴한이...
# 2              코로나19 산학연 회의 참석…"방역 모범국가 됐듯 치료제·백신 앞...
# 3           여 "'민주당에서 n번방 연루자가 나올 것'이란 예언 나와"야 "저쪽에...
# ...

# %%
get_top_30('정치')
# Out:
#                                                 title  \
# 0     [속보] 문 대통령 “코로나19 치료제·백신 개발, 우리가 앞서가야…2100억 투자”
# 1                     [속보]오세훈 후보에게 흉기 든 괴한 접근하다 제압 당해
# 2                   문 대통령 "우리의 치료제와 백신으로 인류생명 구하길 기대"
# 3                          "곧 터진다" 여권서 연일 나오는 음모론의 정체
# 4          文대통령 "치료제·백신은 코로나19 극복 위해 반드시 넘어야 할 산"(속보)
# 5                 원유철 '핑크가발' 때아닌 퀴어 논란···황교안 "꼭 써야하나"
# 6                     탁현민 "문 대통령 지지율 57%인데 누가 누굴 지키나"
# 7   김종인, “입담아선 안될 말 죄송…대학(원)생에 100만원씩”…막말 뿔난 표심 현금...
# 8              [속보]文대통령 “백신 개발에 2100억 투자…방역처럼 모범국 희망”
# 9   [2020 우리의 선택] [여론조사] '광진을' 고민정 49.6% vs 오세훈 39.4%
# 10                         김종인, 고개 숙였지만…차명진은 사과하지 않았다
# 11          김종인 '막말 논란'에 대국민 사과... "너무 절박해, 한 번만 기회를"
# 12          홍준표 '홍새로이' 패러디에 '이태원 클라쓰' 원작자 반발....결국 삭제
# 13                      막말 파문에 고개 숙인 김종인 "한번만 기회를 달라"
# 14          김종인, '막말' 대국민 사과…"입에 올려선 안될 말, 정말 죄송"(종합)
# 15                오세훈 후보 유세 차량에 흉기 든 남성 위협, 경찰 곧바로 제압
# ...
